# %% [markdown]
# **Importing Libraries and Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('P39-Financial-Data.csv')

# %%
df
# Out:
#        entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0       7629673   40     bi-weekly           1    3135                0
# 1       3560428   61        weekly           0    3180                0
# 2       6934997   23        weekly           0    1540                6
# 3       5682812   40     bi-weekly           0    5230                0
# 4       5335819   33  semi-monthly           0    3590                0
# ...         ...  ...           ...         ...     ...              ...
# 17903   9949728   31       monthly           0    3245                0
# 17904   9442442   46     bi-weekly           0    6525                0
# 17905   9857590   46        weekly           0    2685                0
# 17906   8708471   42     bi-weekly           0    2515                0
# 17907   1498559   29        weekly           1    2665                0
#
#        years_employed  current_address_year  personal_account_m  \
# ...

# %% [markdown]
# **Data Visualization**

# %% [markdown]
# Cleaning the Data

# %%
df.describe()
# Out:
#            entry_id           age    home_owner        income  \
# count  1.790800e+04  17908.000000  17908.000000  17908.000000
# mean   5.596978e+06     43.015412      0.425173   3657.214653
# std    2.562473e+06     11.873107      0.494383   1504.890063
# min    1.111398e+06     18.000000      0.000000    905.000000
# 25%    3.378999e+06     34.000000      0.000000   2580.000000
# 50%    5.608376e+06     42.000000      0.000000   3260.000000
# 75%    7.805624e+06     51.000000      1.000000   4670.000000
# max    9.999874e+06     96.000000      1.000000   9985.000000
#
#        months_employed  years_employed  current_address_year  \
# count     17908.000000    17908.000000          17908.000000
# mean          1.186006        3.526860              3.584711
# std           2.400897        2.259732              2.751937
# min           0.000000        0.000000              0.000000
# 25%           0.000000        2.000000              2.000000
# ...

# %%
# df.isna().sum()
df.isna().any()
# Out:
# entry_id                False
# age                     False
# pay_schedule            False
# home_owner              False
# income                  False
# months_employed         False
# years_employed          False
# current_address_year    False
# personal_account_m      False
# personal_account_y      False
# has_debt                False
# amount_requested        False
# risk_score              False
# risk_score_2            False
# risk_score_3            False
# risk_score_4            False
# risk_score_5            False
# ext_quality_score       False
# ext_quality_score_2     False
# inquiries_last_month    False
# e_signed                False
# dtype: bool

# %% [markdown]
# Histograms

# %%
df_temp = df.drop(columns=['entry_id','pay_schedule','e_signed'])

# %%
plt.figure(figsize=(15,15))
plt.suptitle('Histograms of Numerical Columns',fontsize=20)
for i in range(1,df_temp.shape[1]+1):
    plt.subplot(6,3,i) 
    f = plt.gca()
    f.set_title(df_temp.columns.values[i-1])

    vals = np.size(df_temp.iloc[:,i-1].unique())
    if vals>=100:
        vals=100

    plt.hist(df_temp.iloc[:,i-1],bins=vals,color='#3F5D7D')

plt.tight_layout(rect = [0,0.03,1,0.95])

# %%
#we see that there are several people in the months_employed feature that have 0 months employed. This is very unusual and leads to the fact that this feature can be inaccurate.

# %% [markdown]
# Correlation Plot (with response variable)

# %%
c = ['red', 'yellow', 'black', 'blue', 'orange','green','violet']
df_temp.corrwith(df['e_signed']).plot(kind='bar',figsize=(20,10),title='Correlation with E Signed Column',fontsize=15,rot=45,grid=True,color=c)
# Out:
# <AxesSubplot: title={'center': 'Correlation with E Signed Column'}>

# %%
#this correlation is linear in nature so this may change when we run models not linear in nature like random forest, SVM, etc.

# %% [markdown]
# Correlation Matrix

# %%
sns.set(style='white',font_scale = 2)     #background
corr = df_temp.corr()    #actual correlation

f,ax = plt.subplots(figsize=(18,15))    #set up matplotlib figure
f.suptitle("Correlation Matrix",fontsize=48)

cmap = sns.diverging_palette(220,10,as_cmap=True)     #set up a custom diverging colormap

sns.heatmap(corr,cmap=cmap,vmax=0.3,center=0,square=True,linewidths=0.5,cbar_kws={"shrink":0.5})
# Out:
# <AxesSubplot: >

# %% [markdown]
# **Data Preprocessing**

# %% [markdown]
# Feature Engineering

# %%
import random
import time

# %%
df
# Out:
#        entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0       7629673   40     bi-weekly           1    3135                0
# 1       3560428   61        weekly           0    3180                0
# 2       6934997   23        weekly           0    1540                6
# 3       5682812   40     bi-weekly           0    5230                0
# 4       5335819   33  semi-monthly           0    3590                0
# ...         ...  ...           ...         ...     ...              ...
# 17903   9949728   31       monthly           0    3245                0
# 17904   9442442   46     bi-weekly           0    6525                0
# 17905   9857590   46        weekly           0    2685                0
# 17906   8708471   42     bi-weekly           0    2515                0
# 17907   1498559   29        weekly           1    2665                0
#
#        years_employed  current_address_year  personal_account_m  \
# ...

# %%
#getting rid of columns that we found faulty
df=df.drop(columns=['months_employed'])

# %%
#we have 2 columns personal_account_m and personal_account_y
#combining both columns 
df['personal_account_months'] = (df.personal_account_m+(df.personal_account_y*12))

# %%
df[['personal_account_months','personal_account_m','personal_account_y']].head()
# Out:
#    personal_account_months  personal_account_m  personal_account_y
# 0                       30                   6                   2
# 1                       86                   2                   7
# 2                       19                   7                   1
# 3                       86                   2                   7
# 4                       98                   2                   8

# %%
df=df.drop(columns=['personal_account_m','personal_account_y'])

# %% [markdown]
# One Hot Encoding

# %%
df = pd.get_dummies(df)

# %%
df.columns
# Out:
# Index(['entry_id', 'age', 'home_owner', 'income', 'years_employed',
#        'current_address_year', 'has_debt', 'amount_requested', 'risk_score',
#        'risk_score_2', 'risk_score_3', 'risk_score_4', 'risk_score_5',
#        'ext_quality_score', 'ext_quality_score_2', 'inquiries_last_month',
#        'e_signed', 'personal_account_months', 'pay_schedule_bi-weekly',
#        'pay_schedule_monthly', 'pay_schedule_semi-monthly',
#        'pay_schedule_weekly'],
#       dtype='object')

# %%
#we need to remove one of the newly created columns to avoid the DUMMY VARIABLE TRAP
df=df.drop(columns = ['pay_schedule_semi-monthly'])

# %% [markdown]
# Removing Extra Columns

# %%
response = df['e_signed']
user_identifier = df['entry_id']
df=df.drop(columns=['e_signed','entry_id'])

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df,response,test_size=0.2, random_state=0)

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled = pd.DataFrame(sc.fit_transform(X_train))

# %%
X_test_scaled = pd.DataFrame(sc.transform(X_test))

# %%
X_train_scaled.columns = X_train.columns.values
X_test_scaled.columns = X_test.columns.values
X_train_scaled.index = X_train.index.values
X_test_scaled.index = X_test.index.values

# %%
X_train = X_train_scaled
X_test = X_test_scaled

# %% [markdown]
# **Model Building**

# %% [markdown]
# Comparing Models

# %% [markdown]
# 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0,penalty='l1',solver='liblinear')  #lasso penalty

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(penalty='l1', random_state=0, solver='liblinear')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
acc=accuracy_score(y_test,y_pred)
prec=precision_score(y_test,y_pred)
rec=recall_score(y_test,y_pred)
f1=f1_score(y_test,y_pred)

# %%
results = pd.DataFrame([['Logistic Regression (Lasso)',acc,prec,rec,f1]],columns=['Model','Accuracy','Precision','Recall','F1'])
results
# Out:
#                          Model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression (Lasso)  0.561977   0.575963  0.705913  0.634351

# %% [markdown]
# 2. SVM (Linear)

# %%
from sklearn.svm import SVC
classifier = SVC(random_state=0, kernel='linear') 
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
acc=accuracy_score(y_test,y_pred)
prec=precision_score(y_test,y_pred)
rec=recall_score(y_test,y_pred)
f1=f1_score(y_test,y_pred)
model_results = pd.DataFrame([['SVM (Linear)',acc,prec,rec,f1]],columns=['Model','Accuracy','Precision','Recall','F1'])
results = results.append(model_results, ignore_index=True)
results
# Out:
# C:\Users\Devansh Gupta\AppData\Local\Temp\ipykernel_19764\1238044703.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(model_results, ignore_index=True)
#                          Model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression (Lasso)  0.561977   0.575963  0.705913  0.634351
# 1                 SVM (Linear)  0.568398   0.577832  0.735477  0.647193

# %% [markdown]
# 3. SVM (RBF)

# %%
from sklearn.svm import SVC
classifier = SVC(random_state=0, kernel='rbf') 
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
acc=accuracy_score(y_test,y_pred)
prec=precision_score(y_test,y_pred)
rec=recall_score(y_test,y_pred)
f1=f1_score(y_test,y_pred)
model_results = pd.DataFrame([['SVM (RBF)',acc,prec,rec,f1]],columns=['Model','Accuracy','Precision','Recall','F1'])
results = results.append(model_results, ignore_index=True)
results
# Out:
# C:\Users\Devansh Gupta\AppData\Local\Temp\ipykernel_19764\2016111911.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(model_results, ignore_index=True)
#                          Model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression (Lasso)  0.561977   0.575963  0.705913  0.634351
# 1                 SVM (Linear)  0.568398   0.577832  0.735477  0.647193
# 2                    SVM (RBF)  0.591569   0.605730  0.690871  0.645505

# %% [markdown]
# 4. Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(random_state=0, n_estimators=100, criterion='entropy') 
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
acc=accuracy_score(y_test,y_pred)
prec=precision_score(y_test,y_pred)
rec=recall_score(y_test,y_pred)
f1=f1_score(y_test,y_pred)
model_results = pd.DataFrame([['Random Forest',acc,prec,rec,f1]],columns=['Model','Accuracy','Precision','Recall','F1'])
results = results.append(model_results, ignore_index=True)
results
# Out:
# C:\Users\Devansh Gupta\AppData\Local\Temp\ipykernel_19764\523766065.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(model_results, ignore_index=True)
#                          Model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression (Lasso)  0.561977   0.575963  0.705913  0.634351
# 1                 SVM (Linear)  0.568398   0.577832  0.735477  0.647193
# 2                    SVM (RBF)  0.591569   0.605730  0.690871  0.645505
# 3                Random Forest  0.621720   0.640098  0.678942  0.658948

# %% [markdown]
# Saving the Results

# %%
results.to_csv('model_results.csv', index=False)

# %% [markdown]
# K-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier, X=X_train, y=y_train, cv=10)
print("Accuracy: %0.2f"%(accuracies.mean()))
# Out:
# Accuracy: 0.63

# %% [markdown]
# **Improving the model**

# %% [markdown]
# Grid Search

# %% [markdown]
# Round 1: Entropy

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'max_depth':[3,None],'max_features':[1,5,10],'min_samples_split':[2,5,10],'min_samples_leaf':[1,5,10],"bootstrap":[True, False],'criterion':['entropy']}

grid_search = GridSearchCV(estimator=classifier, param_grid = parameters,scoring='accuracy',cv=10,n_jobs=-1)   #n_jobs takes a toll on your computer if changed to -1

# %%
t0=time.time()
grid_search = grid_search.fit(X_train,y_train)
t1=time.time()
print('%0.2f deconds taken'%(t1-t0))
# Out:
# 790.19 deconds taken

# %%
rf_best_accuracy = grid_search.best_score_
rf_best_accuracy
# Out:
# 0.6345122647725013

# %%
rf_best_parameters = grid_search.best_params_
rf_best_parameters
# Out:
# {'bootstrap': True,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 5,
#  'min_samples_leaf': 5,
#  'min_samples_split': 2}

# %% [markdown]
# Round 2: Testing new parameters on Test Set

# %%
y_pred = grid_search.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
acc=accuracy_score(y_test,y_pred)
prec=precision_score(y_test,y_pred)
rec=recall_score(y_test,y_pred)
f1=f1_score(y_test,y_pred)
model_results = pd.DataFrame([['Random Forest (Grid Search: Entropy)',acc,prec,rec,f1]],columns=['Model','Accuracy','Precision','Recall','F1'])
results = results.append(model_results, ignore_index=True)
results
# Out:
# C:\Users\Devansh Gupta\AppData\Local\Temp\ipykernel_19764\3912564036.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(model_results, ignore_index=True)
#                                   Model  Accuracy  Precision    Recall  \
# 0           Logistic Regression (Lasso)  0.561977   0.575963  0.705913
# 1                          SVM (Linear)  0.568398   0.577832  0.735477
# 2                             SVM (RBF)  0.591569   0.605730  0.690871
# 3                         Random Forest  0.621720   0.640098  0.678942
# 4  Random Forest (Grid Search: Entropy)  0.630653   0.645223  0.697095
#
#          F1
# 0  0.634351
# 1  0.647193
# 2  0.645505
# 3  0.658948
# 4  0.670157

# %% [markdown]
# Round 3: Gini

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'max_depth':[3,None],'max_features':[1,6,12],'min_samples_split':[2,5,10],'min_samples_leaf':[1,6,12],"bootstrap":[True, False],'criterion':['gini']}

grid_search = GridSearchCV(estimator=classifier, param_grid = parameters,scoring='accuracy',cv=10,n_jobs=-1)   #n_jobs takes a toll on your computer if changed to -1

# %%
t0=time.time()
grid_search = grid_search.fit(X_train,y_train)
t1=time.time()
print('%0.2f seconds taken'%(t1-t0))
# Out:
# 623.98 seconds taken

# %%
rf_best_accuracy = grid_search.best_score_
rf_best_accuracy
# Out:
# 0.6345824870276445

# %%
rf_best_parameters = grid_search.best_params_
rf_best_parameters
# Out:
# {'bootstrap': False,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 6,
#  'min_samples_leaf': 1,
#  'min_samples_split': 10}

# %% [markdown]
# Round 4: Testing new parameters on Test Set

# %%
y_pred = grid_search.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
acc=accuracy_score(y_test,y_pred)
prec=precision_score(y_test,y_pred)
rec=recall_score(y_test,y_pred)
f1=f1_score(y_test,y_pred)
model_results = pd.DataFrame([['Random Forest (Grid Search: Gini)',acc,prec,rec,f1]],columns=['Model','Accuracy','Precision','Recall','F1'])
results = results.append(model_results, ignore_index=True)
results
# Out:
# C:\Users\Devansh Gupta\AppData\Local\Temp\ipykernel_19764\2061542988.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(model_results, ignore_index=True)
#                                   Model  Accuracy  Precision    Recall  \
# 0           Logistic Regression (Lasso)  0.561977   0.575963  0.705913
# 1                          SVM (Linear)  0.568398   0.577832  0.735477
# 2                             SVM (RBF)  0.591569   0.605730  0.690871
# 3                         Random Forest  0.621720   0.640098  0.678942
# 4  Random Forest (Grid Search: Entropy)  0.630653   0.645223  0.697095
# 5     Random Forest (Grid Search: Gini)  0.628141   0.645366  0.686203
#
#          F1
# 0  0.634351
# 1  0.647193
# 2  0.645505
# 3  0.658948
# 4  0.670157
# 5  0.665158

# %%
results.to_csv('model_results.csv', index=False)
